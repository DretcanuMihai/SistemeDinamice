# %%
#1a)
var("t")
x=function("x")(t)
y=function("y")(t)
eq1=diff(x,t)==x+4*y
eq2=diff(y,t)==x+y
desolve_system([eq1,eq2],[x,y])
# Out:
# [x(t) == 1/2*(x(0) + 2*y(0))*e^(3*t) + 1/2*(x(0) - 2*y(0))*e^(-t),
#  y(t) == 1/4*(x(0) + 2*y(0))*e^(3*t) - 1/4*(x(0) - 2*y(0))*e^(-t)]

# %%
#1b)
var("t")
x=function("x")(t)
y=function("y")(t)
eq1=diff(x,t)==2*x-y
eq2=diff(y,t)==x+2*y
desolve_system([eq1,eq2],[x,y])
# Out:
# [x(t) == (cos(t)*x(0) - sin(t)*y(0))*e^(2*t),
#  y(t) == (sin(t)*x(0) + cos(t)*y(0))*e^(2*t)]

# %%
#1c)
var("t")
x=function("x")(t)
y=function("y")(t)
z=function("z")(t)
eq1=diff(x,t)==x-y+z
eq2=diff(y,t)==x+y-z
eq3=diff(z,t)==-y+2*z
desolve_system([eq1,eq2,eq3],[x,y,z])
# Out:
# [x(t) == t*e^t*x(0) - t*e^t*z(0) - (x(0) + y(0) - 2*z(0))*e^(2*t) + (2*x(0) + y(0) - 2*z(0))*e^t,
#  y(t) == t*e^t*x(0) - t*e^t*z(0) + e^t*y(0),
#  z(t) == t*e^t*x(0) - t*e^t*z(0) - (x(0) + y(0) - 2*z(0))*e^(2*t) + (x(0) + y(0) - z(0))*e^t]

# %%
#1d)
var("t")
x=function("x")(t)
y=function("y")(t)
eq1=diff(x,t)==5*x+3*y+1
eq2=diff(y,t)==-6*x-4*y+e^(-t)
desolve_system([eq1,eq2],[x,y])
# Out:
# [x(t) == 1/3*(6*x(0) + 3*y(0) + 4)*e^(2*t) - t*e^(-t) - 1/3*(3*x(0) + 3*y(0) - 2)*e^(-t) - 2,
#  y(t) == -1/3*(6*x(0) + 3*y(0) + 4)*e^(2*t) + 2*t*e^(-t) + 1/3*(6*x(0) + 6*y(0) - 5)*e^(-t) + 3]

# %%
#1e)
var("t")
x=function("x")(t)
y=function("y")(t)
eq1=diff(x,t)==x+3*y-cos(t)
eq2=diff(y,t)==x-y+2*t
desolve_system([eq1,eq2],[x,y])
# Out:
# [x(t) == 3/40*(10*x(0) + 10*y(0) + 1)*e^(2*t) + 1/40*(10*x(0) - 30*y(0) - 11)*e^(-2*t) - 3/2*t + 1/5*cos(t) - 1/5*sin(t),
#  y(t) == 1/40*(10*x(0) + 10*y(0) + 1)*e^(2*t) - 1/40*(10*x(0) - 30*y(0) - 11)*e^(-2*t) + 1/2*t + 1/5*cos(t) - 1/2]

# %%
#1c)
var("t")
x=function("x")(t)
y=function("y")(t)
z=function("z")(t)
eq1=diff(x,t)==x-2*y-2*z+e^(-t)
eq2=diff(y,t)==-2*x+y+2*z
eq3=diff(z,t)==2*x-y-3*z+e^(-t)
desolve_system([eq1,eq2,eq3],[x,y,z])
# Out:
# [x(t) == 1/3*sqrt(3)*(2*x(0) - y(0) - 2*z(0))*sinh(sqrt(3)*t) + t*e^(-t) + (x(0) + y(0))*e^(-t) - cosh(sqrt(3)*t)*y(0),
#  y(t) == -1/3*sqrt(3)*(2*x(0) - y(0) - 2*z(0))*sinh(sqrt(3)*t) + cosh(sqrt(3)*t)*y(0),
#  z(t) == sqrt(3)*(x(0) - z(0))*sinh(sqrt(3)*t) - (x(0) + y(0) - z(0))*cosh(sqrt(3)*t) + t*e^(-t) + (x(0) + y(0))*e^(-t)]

# %%
#2a)
var("t")
x=function("x")(t)
y=function("y")(t)
eq1=diff(x,t)==x+4*y
eq2=diff(y,t)==x+y
s=desolve_system([eq1,eq2],[x,y],ics=[0,1,2])
show(s)
plot1=plot(s[0].rhs(),(t,-1,1))
plot2=plot(s[1].rhs(),(t,-1,1))
plotf=plot1+plot2
show(plotf)
# Out:
# [x(t) == 5/2*e^(3*t) - 3/2*e^(-t), y(t) == 5/4*e^(3*t) + 3/4*e^(-t)]
# Graphics object consisting of 2 graphics primitives

# %%
#2b)
var("t")
x=function("x")(t)
y=function("y")(t)
eq1=diff(x,t)==x-y+t-1
eq2=diff(y,t)==-2*x+4*y+cos(t)
s=desolve_system([eq1,eq2],[x,y],ics=[0,0,1])
show(s)
plot1=plot(s[0].rhs(),(t,-1,1))
plot2=plot(s[1].rhs(),(t,-1,1))
plotf=plot1+plot2
show(plotf)
# Out:
# [x(t) == -1/13*(10*sqrt(17)*sinh(1/2*sqrt(17)*t) - 33*cosh(1/2*sqrt(17)*t))*e^(5/2*t) - 2*t - 1/26*cos(t) + 5/26*sin(t) - 5/2,
#  y(t) == -1/26*(3*sqrt(17)*sinh(1/2*sqrt(17)*t) - 71*cosh(1/2*sqrt(17)*t))*e^(5/2*t) - t - 3/13*cos(t) + 2/13*sin(t) - 3/2]
# Graphics object consisting of 2 graphics primitives

# %%
#2c)
var("t")
x=function("x")(t)
y=function("y")(t)
eq1=diff(x,t)==x+2*y+e^(-t)
eq2=diff(y,t)==-2*x+y+1
s=desolve_system([eq1,eq2],[x,y],ics=[0,1,1])
show(s)
plot1=plot(s[0].rhs(),(t,-1,1))
plot2=plot(s[1].rhs(),(t,-1,1))
plotf=plot1+plot2
show(plotf)
# Out:
# [x(t) == 1/20*(17*cos(2*t) + 29*sin(2*t))*e^t - 1/4*e^(-t) + 2/5,
#  y(t) == 1/20*(29*cos(2*t) - 17*sin(2*t))*e^t - 1/4*e^(-t) - 1/5]
# Graphics object consisting of 2 graphics primitives

# %%
#2d)
var("t")
x=function("x")(t)
y=function("y")(t)
z=function("z")(t)
eq1=diff(x,t)==-x+3*y+3*z+27*t^2
eq2=diff(y,t)==2*x-2*y-5*z+3*t
eq3=diff(z,t)==-2*x+3*y+6*z+3
s=desolve_system([eq1,eq2,eq3],[x,y,z],ics=[0,50,-30,26])
show(s)
plot1=plot(s[0].rhs(),(t,-1,1))
plot2=plot(s[1].rhs(),(t,-1,1))
plot3=plot(s[2].rhs(),(t,-1,1))
plotf=plot1+plot2+plot3
show(plotf)
# Out:
# [x(t) == 27*t^2 - 63*t + 2*e^(-t) + 3*e^t + 45,
#  y(t) == -18*t^2 + 24*t + e^(3*t) - e^(-t) + 2*e^t - 32,
#  z(t) == 18*t^2 - 27*t - e^(3*t) + e^(-t) + 26]
# Graphics object consisting of 3 graphics primitives

# %%
#3a)
var("t")
x=function("x")(t)
y=function("y")(t)
eq1=diff(x,t,1)==x+y
eq2=diff(y,t,1)==-2*x+4*y
sol1=desolve_system([eq1,eq2],[x,y],ics=[0,3,0])
sol2=desolve_system([eq1,eq2],[x,y],ics=[0,0,3])
sol3=desolve_system([eq1,eq2],[x,y],ics=[0,-3,0])
show(sol1)
show(sol2)
show(sol3)
# Out:
# [x(t) == -3*e^(3*t) + 6*e^(2*t), y(t) == -6*e^(3*t) + 6*e^(2*t)]
# [x(t) == 3*e^(3*t) - 3*e^(2*t), y(t) == 6*e^(3*t) - 3*e^(2*t)]
# [x(t) == 3*e^(3*t) - 6*e^(2*t), y(t) == 6*e^(3*t) - 6*e^(2*t)]

# %%
#3b)
show(limit(sol1[0].rhs(),t=+infinity),limit(sol1[1].rhs(),t=+infinity))
show(limit(sol2[0].rhs(),t=+infinity),limit(sol2[1].rhs(),t=+infinity))
show(limit(sol3[0].rhs(),t=+infinity),limit(sol3[1].rhs(),t=+infinity))
# Out:
# -Infinity -Infinity
# +Infinity +Infinity
# +Infinity +Infinity

# %%
#3c)
f1(u,v)=u+v
f2(u,v)=-2*u+4*v
n(u,v)=sqrt(f1(u,v)^2+f2(u,v)^2)
desen1=plot_vector_field([f1(u,v)/n(u,v),f2(u,v)/n(u,v)],[u,-10,10],[v,-10,10],aspect_ratio=1)
desen2=parametric_plot([sol1[0].rhs(),sol1[1].rhs()],(t,0,5))
desen3=parametric_plot([sol2[0].rhs(),sol2[1].rhs()],(t,0,5))
desen4=parametric_plot([sol3[0].rhs(),sol3[1].rhs()],(t,0,5))
desenf=desen1+desen2+desen3+desen4
desenf.set_axes_range(xmin=-10, xmax=10,ymin=-10,ymax=10)
show(desenf)
# Out:
# Graphics object consisting of 4 graphics primitives

# %%
#4a)
var("t")
x=function("x")(t)
y=function("y")(t)
eq1=diff(x,t)==y
eq2=diff(y,t)==-x-2*y
sol_general=desolve_system([eq1,eq2],[x,y])
show(sol_general)
# Out:
# [x(t) == t*e^(-t)*x(0) + e^(-t)*x(0), y(t) == -t*e^(-t)*x(0)]

# %%
#4b)
show(limit(sol_general[0].rhs(),t=+infinity)," and ",limit(sol_general[1].rhs(),t=+infinity))
# Out:
# 0 ' and ' 0

# %%
#4c)
f1(u,v)=v
f2(u,v)=-u-2*v
n(u,v)=sqrt(f1(u,v)^2+f2(u,v)^2)
plot_vector_field([f1(u,v)/n(u,v),f2(u,v)/n(u,v)],(u,-10,10),(v,-10,10),aspect_ratio=1)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#5a)
f1(u,v)=2*u+v
f2(u,v)=u+2*v
n(u,v)=sqrt(f1(u,v)^2+f2(u,v)^2)
plot_vector_field([f1(u,v)/n(u,v),f2(u,v)/n(u,v)],[u,-10,10],[v,-10,10],aspect_ratio=1)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#5b)
f1(u,v)=-u-v
f2(u,v)=u-v
n(u,v)=sqrt(f1(u,v)^2+f2(u,v)^2)
plot_vector_field([f1(u,v)/n(u,v),f2(u,v)/n(u,v)],[u,-10,10],[v,-10,10],aspect_ratio=1)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#5c)
f1(u,v)=v
f2(u,v)=-u
n(u,v)=sqrt(f1(u,v)^2+f2(u,v)^2)
plot_vector_field([f1(u,v)/n(u,v),f2(u,v)/n(u,v)],[u,-10,10],[v,-10,10],aspect_ratio=1)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#5d)
f1(u,v)=-2*u
f2(u,v)=-4*u-2*v
n(u,v)=sqrt(f1(u,v)^2+f2(u,v)^2)
plot_vector_field([f1(u,v)/n(u,v),f2(u,v)/n(u,v)],[u,-10,10],[v,-10,10],aspect_ratio=1)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#5e)
f1(u,v)=u-4*v
f2(u,v)=5*u-3*v
n(u,v)=sqrt(f1(u,v)^2+f2(u,v)^2)
plot_vector_field([f1(u,v)/n(u,v),f2(u,v)/n(u,v)],[u,-10,10],[v,-10,10],aspect_ratio=1)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#5f)
f1(u,v)=3*u-v
f2(u,v)=v
n(u,v)=sqrt(f1(u,v)^2+f2(u,v)^2)
plot_vector_field([f1(u,v)/n(u,v),f2(u,v)/n(u,v)],[u,-10,10],[v,-10,10],aspect_ratio=1)
# Out:
# Graphics object consisting of 1 graphics primitive
